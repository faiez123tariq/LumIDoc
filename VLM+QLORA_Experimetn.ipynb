# %% [markdown]
# # Assignment No. 5 — Generative AI (AI4009)
# # Vision Language Model (VLM) Fine-Tuning with QLoRA
# ## Document-to-Markdown Generation using Qwen2-VL-2B-Instruct
#
# **National University of Computer and Emerging Sciences | Spring 2026**
#
# > 🖥️ **Platform**: Google Colab | Runtime → Change runtime type → **T4 GPU**
#
# ---
# ### Objective
# Fine-tune **Qwen2-VL-2B-Instruct** using **QLoRA** to convert document images into structured Markdown using the Nougat dataset.
#
# ### Covers
# - Multimodal learning (image + text) | Parameter-efficient fine-tuning
# - Markdown generation | Gradio App | All 3 Bonus Tasks

# %% [markdown]
# ---
# ## ✅ Step 0A: Connect Google Drive (for saving model checkpoints)
# Colab sessions reset after ~12 hours. Saving to Drive ensures your fine-tuned model is not lost.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# All outputs will be saved here — change folder name if you want
DRIVE_SAVE_DIR = '/content/drive/MyDrive/GenAI_Assignment5'
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)

print(f"Drive mounted. Saving outputs to: {DRIVE_SAVE_DIR}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted. Saving outputs to: /content/drive/MyDrive/GenAI_Assignment5

# %% [markdown]
# ---
# ## ✅ Step 0B: Check GPU & Install Dependencies

# %%
# Check GPU assigned by Colab
import subprocess
result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
print(result.stdout)

# Tip: If you don't see a GPU here, go to:
# Runtime → Change runtime type → Hardware accelerator → T4 GPU → Save
# Out:
# Sun May  3 12:24:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Install bitsandbytes for 4-bit quantization
# !pip install -U bitsandbytes>=0.46.1

print("✅ bitsandbytes installed/updated!")
# Out:
# ✅ bitsandbytes installed/updated!

# %%
# Install only packages required for dataset loading
# !pip install -q kagglehub
# !pip install -q datasets
# !pip install -q Pillow

print("✅ Required packages installed for dataset loading!")
# Out:
# ✅ Required packages installed for dataset loading!

# %%
# Install KaggleHub for dataset download
# !pip install -q kagglehub

# %%
import os
from PIL import Image
from functools import partial
from datasets import load_dataset
import numpy as np

# ── Colab working directory ───────────────────────────────────────────────────
WORK_DIR   = '/content/vlm_assignment'
os.makedirs(WORK_DIR,  exist_ok=True)
print(f"Working dir : {WORK_DIR}")
# Out:
# Working dir : /content/vlm_assignment

# %%
import kagglehub
import os

# Download latest version of the Kaggle dataset
print("Downloading Nougat dataset from KaggleHub...")
print("(This may take a few minutes)")
kaggle_dataset_path = kagglehub.dataset_download("zphilip/nougat-training-dataset-example")

print(f"\n✅ Kaggle dataset downloaded to: {kaggle_dataset_path}")
# Out:
# Downloading Nougat dataset from KaggleHub...
# (This may take a few minutes)
# Using Colab cache for faster access to the 'nougat-training-dataset-example' dataset.
#
# ✅ Kaggle dataset downloaded to: /kaggle/input/nougat-training-dataset-example

# %% [markdown]
# ---
# ## Part 1: Dataset Exploration
#
# Loading the **Nougat** dataset directly from HuggingFace Hub.
# Each sample = document image (scientific paper page) + ground-truth Markdown.

# %%
import os
from datasets import load_dataset
from PIL import Image, UnidentifiedImageError
from functools import partial

# ── Helper function to load image from path and prepare markdown ──────────────
def load_image_and_markdown(sample, base_dir):
    # Corrected: Use 'image' key for image path and 'markdown' for text
    image_path_rel = sample.get('image')
    md_text = sample.get('markdown', '')

    if not image_path_rel or not base_dir:
        return {"image": None, "markdown": md_text} # Indicate skipped

    # The image paths in 0508.jsonl are relative to the '0508' directory,
    # which is inside the kaggle_dataset_path. We need to construct the
    # correct full path.
    full_image_path = os.path.join(base_dir, image_path_rel)
    try:
        image = Image.open(full_image_path).convert('RGB')
    except (FileNotFoundError, UnidentifiedImageError):
        print(f"Warning: Image file issue at {full_image_path}. Skipping sample.")
        return {"image": None, "markdown": md_text}

    return {"image": image, "markdown": md_text}

# ── Load Nougat dataset from KaggleHub ─────────────────────────────────────
print(f"Loading Nougat dataset from local KaggleHub path: {kaggle_dataset_path}...")

# The Kaggle dataset has a single JSONL file '0508.jsonl' in the root.
data_file = os.path.join(kaggle_dataset_path, "0508.jsonl")

# Load as a single dataset (it will default to 'train' split)
raw_dataset = load_dataset("json", data_files=data_file, split='train')

# Map the raw dataset to have 'image' (PIL Image) and 'markdown' (str) features
# The 'image' key from the raw dataset is transformed into a PIL Image and then removed.
process_sample_fn = partial(load_image_and_markdown, base_dir=kaggle_dataset_path)
nougat_dataset = raw_dataset.map(process_sample_fn, remove_columns=['image', 'meta'])

# Filter out any samples where the image failed to load
nougat_dataset = nougat_dataset.filter(lambda sample: sample['image'] is not None)

print(f"\n✅ Dataset loaded from KaggleHub and processed!")
print(f"Total samples  : {len(nougat_dataset)}")
print(f"Features       : {list(nougat_dataset.features.keys())}")
# Out:
# Loading Nougat dataset from local KaggleHub path: /kaggle/input/nougat-training-dataset-example...
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/14200 [00:00<?, ? examples/s]
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508150/10.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508061/15.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math-ph0508047/01.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508460/16.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508158/14.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508381/11.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/hep-th0508085/45.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/hep-th0508187/19.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/cs0508069/13.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508042/11.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math-ph0508062/37.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508127/29.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508359/03.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508616/31.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math-ph0508005/22.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508100/04.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/physics0508102/04.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508155/32.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508342/21.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508399/02.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508167/03.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508210/05.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508100/17.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508527/14.png. Skipping sample.
# Warning: Image file issue at /kaggle/input/nougat-training-dataset-example/0508/math0508506/17.png. Skipping sample.
# Filter:   0%|          | 0/14200 [00:00<?, ? examples/s]
# ✅ Dataset loaded from KaggleHub and processed!
# Total samples  : 14175
# Features       : ['image', 'markdown']

# %%
# ── Inspect the raw dataset to see image_path values ──────────────────────────
print("Inspecting raw_dataset to check image_path values...")
print("Sample 0 image_path:", raw_dataset[0].get('image_path'))

# Also check the content of the 0508.jsonl for image paths structure
# This assumes 0508.jsonl is a regular text file, not binary.
# Only read first few lines to avoid large output
print(f"\nFirst 5 lines of {data_file}:")
with open(data_file, 'r') as f:
    for i, line in enumerate(f):
        if i >= 5:
            break
        print(line.strip())
# Out:
# Inspecting raw_dataset to check image_path values...
# Sample 0 image_path: None
#
# First 5 lines of /kaggle/input/nougat-training-dataset-example/0508.jsonl:
# {"image": "0508/quant-ph0508208/06.png", "markdown": "ground state is two-fold degenerate, and when \\(B>B_{\\text{th}}\\) the ground state becomes non-degenerate and the corresponding wave function is given by\n\n\\[|\\psi_{0}\\rangle=|-\\frac{1}{2},-1\\rangle,\\] (39)\n\nwhich is obviously of no entanglement. Then, the ground-state negativity forms a platform when \\(0<B<B_{\\text{th}}\\). The jump of negativity at \\(B=B_{\\text{th}}\\) is due to the level crossing. For \\(N>2\\), the effects of magnetic fields on entanglement can be also explained by level crossing. For instance, for \\(N=4\\), there are two level crossing, and the entanglement displays two jumps.\n\n## III Effects of next-nearest-neighbor interactions on entanglement\n\nWe have studied the effects of finite temperature and magnetic fields on entanglement, and now consider the model containing two kinds of spins, spin \\(\\frac{1}{2}\\) and \\(1\\), alternating on a ring with antiferromagnetic exchange coupling between both the NN spins and the NNN spins. The Hamiltonian can be expressed as\n\n\\[H=J_{1}\\sum^{N/2}_{i=1}\\big{(}{\\bf s}_{i}\\cdot{\\bf S}_{i}+{\\bf S}_{i}\\cdot{\\bf s }_{i+1}\\big{)}+J_{2}\\sum^{N/2}_{i=1}\\big{(}{\\bf s}_{i}\\cdot{\\bf s}_{i+1}+{\\bf S }_{i}\\cdot{\\bf S}_{i+1}\\big{)},\\] (40)\n\nwhere the \\({\\bf s}_{i}\\) and \\({\\bf S}_{i}\\) are spin-1/2 and spin-1 operators in the \\(i\\)th cell. \\(J_{1}\\) characterizes the NN exchange coupling and \\(J_{2}\\) the NNN coupling. We consider the antiferromagnetic interaction by taking \\(J_{1},J_{2}>0\\). \\(N\\) is the total number of spins and here we choose it be even. Also we adopt the periodic boundary condition.\n\n### Four-spin model\n\n#### III.1.1 Eigenenergy and ground-state entanglement\n\nThe model with four spins is the simplest model with NNN interactions. We first solve the eigenvalue problem of this model. The key step is to write the four-spin Hamiltonian in the following form,\n\n\\[H =\\] 12{J1S2+(2J2-J1)[(s1+s2)2+(S1+S2)2] (41) \\[-\\] 2J2(s12+s22+S12+S22)},\n\nwhere \\({\\bf S}={\\bf S}_{1}+{\\bf S}_{2}+{\\bf s}_{1}+{\\bf s}_{2}\\) denotes the total spin. From the above form, by angular momentum coupling theory, one can readily obtain all eigenvalues of the system as\n\n\\[E_{1} = J_{2}n(n+1)-\\frac{11}{2}J_{2},\\] \\[E_{2} = nJ_{1}+n(n+1)J_{2}-\\frac{7}{2}J_{2},\\] \\[E_{3} = -J_{1}+n(n+1)J_{2}-\\frac{7}{2}J_{2},\\] \\[E_{4} = -(n+1)J_{1}+n(n+1)J_{2}-\\frac{7}{2}J_{2},\\] (42)\n\nwhere parameter \\(n=0,1,2\\) in expressions \\(E_{1}\\) and \\(E_{2}\\) and \\(n=1,2\\) in expressions \\(E_{3}\\) and \\(E_{4}\\), respectively. Then, from Eq. (42), we may find the ground-state energy as\n\n\\[E_{\\text{GS}}=\\left\\{\\begin{array}[]{ll}-3J_{1}+\\frac{5}{2}J_{2}&\\;\\text{when} \\;\\;\\;0\\leq J_{2}<J_{1}/4,\\\\ -2J_{1}-\\frac{3}{2}J_{2}&\\;\\text{when}\\;\\;\\;J_{1}/4<J_{2}<J_{1}/2,\\\\ -\\frac{11}{2}J_{2}&\\;\\text{when}\\;\\;\\;J_{2}>J_{1}/2,\\end{array}\\right.\\] (43)\n\nClearly, there are two level-crossing points, which will greatly affect behaviors of ground-state entanglement.\n\nFrom Eq. (41), it is obvious that in addition to the the SU\\((2)\\) symmetry, there also exists an exchange symmetry, namely, exchanging two spin halves or two spin ones yields invariant Hamiltonian. Then, the correlator \\(\\langle{\\bf s}_{i}\\cdot{\\bf S}_{i}\\rangle\\) between any NN spins are the same. Therefore, we can get the correlator \\(\\langle{\\bf s}_{i}\\cdot{\\bf S}_{i}\\rangle\\) from the ground-state energy via the Hellmann-Feynman theorem.\n\nWhen \\(0\\leq J_{2}<J_{1}/4\\), after applying the Hellmann-Feynman theorem to the ground-state energy, we obtain\n\n\\[\\langle{\\bf s}_{1}\\cdot{\\bf S}_{1}\\rangle=\\frac{1}{4}\\frac{\\partial E_{0}}{ \\partial J_{1}}=-\\frac{3}{4}.\\] (44)\n\nDue to the SU\\((2)\\) symmetry in our system, we have the following relation between the negativity and the correlator \\(\\langle{\\bf s}_{1}\\cdot{\\bf S}_{1}\\rangle\\)Schliem ...
# {"image": "0508/quant-ph0508208/01.png", "markdown": "# Entanglement properties in (1/2,1) mixed-spin Heisenberg systems\n\nZhe Sun, XiaoGuang Wang, AnZi Hu, and You-Quan Li\n\nZhejiang Institute of Modern Physics, Department of Physics, Zhejiang University, HangZhou 310027, China\n\n(October 12, 2023)\n\n###### Abstract\n\nBy using the concept of negativity, we investigate entanglement in (1/2,1) mixed-spin Heisenberg systems. We obtain the analytical results of entanglement in small isotropic Heisenberg clusters with only nearest-neighbor (NN) interactions up to four spins and in the four-spin Heisenberg model with both NN and next-nearest-neighbor (NNN) interactions. For more spins, we numerically study effects of temperature, magnetic fields, and NNN interactions on entanglement. We study in detail the threshold value of the temperature, after which the negativity vanishes.\n\npacs: 75.10.Jm,03.65.Ud\n\n## I Introduction\n\nEntanglement, an essential feature of the quantum mechanics, has been introduced in many fields of physics. In the field of quantum information, the entanglement has played a key role. The study of entanglement properties in many-body systems have attracted much attention M_Nielsen -QPT_GVidal . The Heisenberg chains, widely studied in the condensed matter field, display rich entanglement features and have many useful applications such as in the quantum state transfer M_Sub .\n\nMost of the systems considered in previous studies are spin-half systems as there exists a good measure of entanglement of two spin-halves, the concurrence Conc , which is applicable to an arbitrary state of two spin halves. On the other hand, the entanglements in mixed-spin or higher spin systems are not well-studied due to the lack of good operational entanglement measures. There are several initial studies along this direction Schliemann ; Yi ; Zhu , however these works are restricted to the case of two particles.\n\nFor the case of higher spins, a non-entangled state has necessarily a positive partial transpose according to the Peres-Horodecki criterion PH . In the case of two spin halves, and the case of (1/2,1) mixed spins, fortunately, a positive partial transpose is also sufficient. Thus, the sufficient and necessary condition for entangled state in (1/2,1) mixed spin systems is that it has a negative partial transpose. This allows us to investigate entanglement features of the mixed spin system.\n\nThe Peres-Horodecki criterion give a qualitative way for judging whether the state is entangled or not. The quantitative version of the criterion was developed by Vidal and Werner Vidal . They presented a measure of entanglement called negativity that can be computed efficiently, and the negativity does not increase under local manipulations of the system. The negativity of a state \\(\\rho\\) is defined as\n\n\\[{\\cal N(\\rho)}=\\sum_{i}|\\mu_{i}|,\\] (1)\n\nwhere \\(\\mu_{i}\\) is the negative eigenvalue of \\(\\rho^{T_{1}}\\), and \\(T_{1}\\) denotes\n\nthe partial transpose with respect to the first system. The negativity \\({\\cal N}\\) is related to the trace norm of \\(\\rho^{T_{1}}\\) via\n\n\\[{\\cal N(\\rho)}=\\frac{\\|\\rho^{T_{1}}\\|_{1}-1}{2},\\] (2)\n\nwhere the trace norm of \\(\\rho^{T_{1}}\\) is equal to the sum of the absolute values of the eigenvalues of \\(\\rho^{T_{1}}\\). In this paper, we will use the concept of negativity to study entanglement in (1/2,1) mixed-spin systems.\n\nAs shown in most previous works, models with the NN exchange interactions are considered and it is not easy to have pairwise entanglement between the NNN spins M_Osborne ; M_Osterloh . It is true that there exist some quasi-one-dimension compounds offering us systems with NNN interactions. Bose and Chattopadhyay Ibose and Gu et al. Gu have investigated entanglement in spin-half Heisenberg chain with NNN interactions. In our paper here, we study entanglement properties not only in the (1/2,1) mixed-spin systems only with NN inter ...
# {"image": "0508/quant-ph0508208/08.png", "markdown": "e can read the threshold temperature \\(T_{\\text{th}}\\) versus different \\(J_{2}\\) from the curve in the \\(J_{2}-T\\) plane. When \\(J_{2}\\) increases, \\(T_{\\text{th}}\\) decreases, and when \\(J_{2}\\) crosses about \\(0.3758\\), \\({\\cal N}_{1/2,1}\\) will disappear at any temperature.\n\nNext, we consider the entanglement between NNN spins. In Fig. 7, we plot the negativity \\({\\cal N}_{1/2,1/2}\\) as a function of the temperature and \\(J_{2}\\). We can see that, before \\(J_{2}\\) reaches the value about \\(J_{2}=0.5\\), \\({\\cal N}_{1/2,1/2}\\) keeps being zero at any temperature. And in the region \\(J_{2}>0.5\\), the \\({\\cal N}_{1/2,1/2}\\) can be enhanced by the increasing NNN interaction. This is a result from the competition of two kinds of exchange interactions. The thermal fluctuation all along suppresses the entanglement. So, from the curve lying on the \\(J_{2}-T\\) plane which corresponds to the boundary of the nonzero and zero values of \\({\\cal N}_{1/2,1/2}\\), we may find that the higher the temperature is, the larger the threshold \\(J_{\\text{2th}}\\) will be. From another point of view, the \\(T_{\\text{th}}\\) increases as \\(J_{2}\\) increases.\n\n\n\nIn Fig. 8, we plot the negativity \\({\\cal N}_{1,1}\\) versus \\(T\\) and \\(J_{2}\\). In the region of \\(J_{2}<0.25\\), \\({\\cal N}_{1,1}\\) is zero at any temperature. When \\(J_{2}>0.25\\), the increasing NNN exchange interaction \\(J_{2}\\) enhances the negativity and exhibits two particular flat roofs. With the temperature rises, \\({\\cal N}_{1,1}\\) is suppressed to zero. Also we can consider the threshold \\(T_{\\text{th}}\\) and \\(J_{\\text{2th}}\\) from the critical curve on the \\(J_{2}-T\\) plane, and the \\(J_{\\text{2th}}\\) also behaves as an increasing function of the temperature. We can see the nonzero region of \\({\\cal N}_{1,1}\\) is much larger than \\({\\cal N}_{1/2,1/2}\\). But here it should be pointed out that, because \\({\\cal N}_{1,1}>0\\) only gives a sufficient condition for entangled state, we can not definitely say that the state in the area of zero negativity is not entangled.\n\n\n\n### Numerical results of negativity for more spins\n\nIn this section, we present numerical results of negativity for more spins, and first consider the low-temperature case.\n\n#### III.2.1 Low-temperature case\n\n\n\n\n\nIn Fig. 9, we plot the negativity versus \\(J_{2}\\) for the case of six spins at a lower temperature. The negativity \\({\\cal N}_{1/2,1}\\) behaves as a decreasing function of \\(J_{2}\\). It decreases to zero at about \\(J_{2}=0.27\\), which is the special point corresponding to the energy level crossing. On the contrary, around the point \\(J_{2}=0.27\\), \\({\\cal N}_{1,1}\\) jumps up to a nonzero value, and then increases gradually until approaching the limit about \\({\\cal N}_{1,1}=0.33\\). This behavior is quite different from that in the four-spin model.\n\nWe also see that \\({\\cal N}_{1/2,1/2}\\) is zero all the time. It can be understood as follows. In the six-site system there are three spin halves with the NNN interaction. Even for a", "meta": []}
# {"image": "0508/quant-ph0508208/04.png", "markdown": "It is straightforward to check that the negativity is always zero. Or, from another way, all the eigenvalues of the matrix \\(\\rho^{T}_{13}\\) are obtained as\n\n\\[\\lambda_{1} = \\left(\\frac{5}{2}e^{-\\frac{5}{4}\\beta}+\\frac{1}{2}e^{\\frac{7}{4} \\beta}\\right)/Z,\\] \\[\\lambda_{2} = \\left(\\frac{5}{6}e^{-\\frac{5}{4}\\beta}+2e^{\\frac{3}{4}\\beta}+ \\frac{1}{6}e^{\\frac{7}{4}\\beta}\\right)/Z,\\] \\[\\lambda_{3} = \\lambda_{4}=a_{2}.\\] (27)\n\nObviously the negativity vanishes here, in other words there is no entanglement between the two spin halves.\n\nThe ground-state negativity \\({\\cal N}_{12}={\\cal N}(\\rho_{12})\\)=1/3 and \\({\\cal N}_{13}={\\cal N}(\\rho_{13})\\)=0, here \\({\\cal N}_{12}\\) denotes the negativity between the \\(1_{\\text{th}}\\) and \\(2_{\\text{th}}\\) spin on the chain and \\({\\cal N}_{13}\\) denotes the one between the \\(1_{\\text{th}}\\) and \\(3_{\\text{th}}\\) spin. The equation above can be obtained from the non-degenerate ground state given by:\n\n\\[|\\psi_{0}\\rangle = \\frac{\\sqrt{6}}{6}\\left(|\\frac{1}{2},0,-\\frac{1}{2}\\rangle+|- \\frac{1}{2},0,\\frac{1}{2}\\rangle\\right)\\] (28) \\[- \\frac{\\sqrt{3}}{3}\\left(|\\frac{1}{2},-1,\\frac{1}{2}\\rangle+|- \\frac{1}{2},1,-\\frac{1}{2}\\rangle\\right).\\]\n\nIt is interesting to see that the ground-state entanglement between the spin half and spin 1 in the three-spin case is the same as that in the two-spin case.\n\nDue to the SU(2) symmetry in our system, there are following relations between correlation functions and negativities Schliemann\n\n\\[{\\cal N}_{12}= -\\frac{1}{3}-\\frac{2}{3}\\langle{\\bf s}_{1}\\cdot{\\bf S}_{1}\\rangle,\\] \\[{\\cal N}_{23}= -\\frac{1}{3}-\\frac{2}{3}\\langle{\\bf S}_{1}\\cdot{\\bf s}_{2}\\rangle,\\] \\[{\\cal N}_{31}= -\\frac{1}{4}-\\langle{\\bf s}_{2}\\cdot{\\bf s}_{1}\\rangle,\\] (29)\n\nwhere we have removed the max function in the negativity, implying that the negative value of \\({\\cal N}\\) indicates no entanglement. Then, we have the relation between the internal energy and the negativities\n\n\\[U= -\\frac{5}{4}-{\\cal N}_{13}-\\frac{3}{2}({\\cal N}_{12}+{\\cal N}_{23})\\] \\[= -\\frac{5}{4}-{\\cal N}_{13}-{3}{\\cal N}_{12}.\\] (30)\n\nThe second equality follows from the exchange symmetry, namely, the Hamiltonian is invariant when exchanging two spin halves. So, for the three-spin case, the internal energy is related to two negativities.\n\nTo apply the above result, we consider the the ground-state properties (\\(T=0\\)). The Hamiltonian can be rewritten as\n\n\\[H=\\frac{1}{2}[({\\bf s}_{1}+{\\bf S}_{1}+{\\bf s}_{2})^{2}-{\\bf s}_{1}^{2}-{\\bf S }_{1}^{2}-{\\bf s}_{2}^{2}].\\] (31)\n\nThen, by the angular momentum coupling theory, the ground-state energy is obtained as \\(E_{0}=-7/4\\). Substituting the ground-state energy and \\({\\cal N}_{12}=1/3\\) to Eq. (30), we obtain \\({\\cal N}_{13}=-1/2\\), indicating that there exists no entanglement between two spin halves. Next, we consider more general situations, i.e., the case of even \\(N\\) sites.\n\n#### II.1.3 The case of even \\(N\\) spins\n\nExcept for the SU(2) symmetry in the system, there exists exchange symmetry for the case of even spins. For instance, in the four-spin model, the Hamiltonian is invariant when exchanging two spin halves or two spin ones. Thus, for even-spin model, the entanglements between the two nearest-neighbor spins and the correlation functions \\(\\langle{\\bf s}_{i}\\cdot{\\bf S}_{i}\\rangle\\) are independent on index \\(i\\). Therefore, the internal energy per spin is equal to the correlation function \\(\\langle{\\bf s}_{i}\\cdot{\\bf S}_{i}\\rangle\\)\n\n\\[u=U/N=\\langle{\\bf s}_{1}\\cdot{\\bf S}_{1}\\rangle.\\] (32)\n\nFrom Eqs. (II.1.2) and (32), we have\n\n\\[{\\cal N}_{12}=-\\frac{1}{3}-\\frac{2}{3}u.\\] (33)\n\nThis equation indicates that for the case of even spins the entanglement between two nearest neighbors is solely determined by ...
# {"image": "0508/quant-ph0508208/05.png", "markdown": "are plotted in Fig. 2 and Fig. 3. It is clear to see that the ground state exhibits maximal entanglement, and with the increase of temperature, the entanglement monotonically decreases until it reaches zero. The decrease of entanglement is due to the mixture of less entangled excited states when increasing the temperature. The existence of the threshold temperature is also evident. For the case of even number of sites (Fig. 2), the threshold temperature decreases with the increase of \\(N\\). In contrast to this behavior, for the case of odd number of spins, as seen from Fig. 3, the threshold temperature increases with the increase of \\(N\\).\n\n\n\n\n\n#### II.2.2 Effects of magnetic fields\n\nWe now examine the effect of magnetic fields on entanglement. The Heisenberg Hamiltonian with a magnetic field along \\(z\\) direction is given by\n\n\\[H_{1}=H_{0}+B\\sum_{i=1}^{N/2}\\big{(}{s}_{iz}+{S}_{i,z}\\big{)},(N\\in\\text{even}).\\] (35)\n\nFor \\(N=2\\), the analytical result of negativity can be obtained (see Appendix A).\n\n\n\nIn Fig. 4, we plot the negativity versus the magnetic field at a low temperature. For the two-spin case, with the increase of the magnetic field, the negativity rapidly reach a platform, and then after a certain magnetic field \\(B_{\\text{th}}\\), it jumps down to zero, indicating no entanglement. When \\(B=0\\), the ground state is two-fold degenerate with \\({\\cal N}=1/3\\). For a small \\(B>0\\), the system is no longer degenerate, and the ground state is given by\n\n\\[|\\psi_{0}\\rangle=\\frac{\\sqrt{6}}{3}|\\frac{1}{2},-1\\rangle-\\frac{\\sqrt{3}}{3}|- \\frac{1}{2},0\\rangle,\\] (36)\n\nwhich is of the Schmidt form. For a state written as its Schmidt form\n\n\\[|\\psi\\rangle=\\sum_{n}c_{n}|e_{n}\\rangle|f_{n}\\rangle,\\] (37)\n\nthe negativity is obtained as Vidal\n\n\\[{\\cal N}=\\left[\\big{(}\\sum_{n}c_{n}\\big{)}^{2}-1\\right]/2.\\] (38)\n\nHere, \\(C_{n}\\) are the Schmidt coefficients, and \\(\\{|e_{n}\\rangle\\}\\) and \\(\\{|f_{n}\\rangle\\}\\) are bases for subsystems 1 and 2, respectively. Applying this formula to the ground state, we immediately have \\({\\cal N}=\\sqrt{2}/3\\). When \\(B=B_{\\text{th}}=3/2\\), the", "meta": []}

# %%
# ── Inspect Kaggle dataset contents ───────────────────────────────────────────
print(f"Contents of {kaggle_dataset_path}:")
for root, dirs, files in os.walk(kaggle_dataset_path):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/02.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/08.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/06.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/01.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/07.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508093/15.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/24.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/06.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/12.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/22.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/23.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/07.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/24.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/23.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/22.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/13.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/19.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508069/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/20.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/21.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508009/19.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/06.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508179/05.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/14.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/08.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508331/04.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/03.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/02.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/01.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/04.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508228/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/24.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/11.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/14.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/12.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/22.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/23.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/24.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/23.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/15.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/22.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508113/13.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/11.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/08.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/12.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/07.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508111/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/20.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/26.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/18.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/12.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/19.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508092/26.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/03.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/02.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/01.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508168/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/03.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/02.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/06.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/07.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508350/05.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508640/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508640/02.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508640/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508640/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508640/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/03.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/09.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/02.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/08.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/10.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/06.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/01.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/07.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/04.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508157/05.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/03.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/09.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/02.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/08.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/10.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/06.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/01.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/07.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/04.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508233/05.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/11.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/03.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/02.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/10.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/12.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/01.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/07.png
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/gr-qc0508030/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508704/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/29.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/27.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/28.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/29.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/28.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508239/27.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508469/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508469/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508469/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/09.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/01.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508163/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/11.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/10.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/12.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508128/13.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508183/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/11.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/09.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/16.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/14.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/10.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/06.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/18.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/12.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/17.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/17.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/16.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/15.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/13.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508321/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/14.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/12.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/13.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508046/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/14.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/20.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/18.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/17.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/17.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/19.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508202/05.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/09.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/08.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/10.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/06.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/07.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508161/05.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/11.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/16.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/14.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/10.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/12.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/16.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/15.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/13.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508269/05.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/11.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/03.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/09.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/02.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/08.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/10.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/06.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/12.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/01.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/07.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/04.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508099/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/24.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/25.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/09.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/10.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/21.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/24.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/25.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508161/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508754/03.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508754/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508754/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508754/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508754/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/09.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/08.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/15.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508586/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508329/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508329/02.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508329/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508329/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508329/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/02.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/21.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/22.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508121/22.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/14.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/07.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508109/04.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508235/01.png
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508235/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508235/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508235/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/quant-ph0508235/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508005/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508005/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508005/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/09.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/02.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/14.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/20.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/06.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/18.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/21.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/01.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/13.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/19.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/04.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508020/05.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/08.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/06.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/07.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508376/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/11.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/27.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/14.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/08.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/26.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/12.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/28.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/07.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/28.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/27.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/13.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/26.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508126/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/11.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/09.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/08.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/10.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/07.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508032/04.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/11.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/03.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/09.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/02.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/14.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/10.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/12.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/15.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/13.png
# /kaggle/input/nougat-training-dataset-example/0508/nlin0508009/04.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/24.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/11.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/25.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/27.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/09.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/02.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/16.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/14.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/10.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/26.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/18.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/21.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/12.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/28.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/22.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/23.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/01.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/17.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/17.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/16.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/24.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/23.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/28.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/15.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/22.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/27.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/13.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/25.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/26.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508060/04.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/03.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508555/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/03.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/09.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/08.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/10.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/07.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508047/05.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/11.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/03.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/02.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/08.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/12.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508006/01.mmd
# ...
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/06.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/12.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508522/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508638/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508638/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508638/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/07.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508014/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508007/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508007/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508007/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/02.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/16.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/10.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/06.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/01.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/17.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/07.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/17.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/16.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/15.png
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cs0508005/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/25.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/27.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/02.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/26.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/01.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/27.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/25.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508348/26.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/02.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/06.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508236/05.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/03.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/02.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/06.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/04.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508032/05.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/06.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/04.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508115/05.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-ex0508029/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-ex0508029/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-ex0508029/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/11.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/03.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/03.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/09.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/14.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/08.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/13.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/20.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/10.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/21.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/12.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/12.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/22.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/07.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/15.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/22.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/13.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/19.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/04.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508230/05.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508393/11.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508393/10.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508393/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508393/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508393/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/11.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/02.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/16.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/10.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/01.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/16.png
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/math0508305/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508055/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508055/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508055/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508055/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508055/04.png
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508335/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508335/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/cond-mat0508335/05.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/09.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/08.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/01.png
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/astro-ph0508664/04.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508054/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508054/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508054/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508012/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508012/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ex0508012/05.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/02.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/01.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/07.png
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/physics0508086/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/09.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/02.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/08.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/06.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/01.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/07.png
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/nucl-th0508031/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/04.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/04.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-ph0508020/05.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/24.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/02.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/11.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/25.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/19.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/15.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/08.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/09.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/02.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/14.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/20.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/08.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/09.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/21.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/20.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/10.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/14.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/06.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/18.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/21.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/18.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/06.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/11.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/23.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/01.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/07.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/meta.json
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/01.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/24.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/23.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/07.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/15.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/10.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/05.mmd
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/25.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/19.png
# /kaggle/input/nougat-training-dataset-example/0508/hep-th0508041/05.png

# %%
import os
from PIL import Image
from functools import partial
from datasets import load_dataset
from io import BytesIO # Add this import

# ── Inspect one sample ────────────────────────────────────────────────────────
sample = nougat_dataset[0]
print("Keys in sample:", list(sample.keys()))

# Get image and markdown — handle different column names
img_key = 'image' if 'image' in sample else 'img'
md_key  = 'markdown' if 'markdown' in sample else 'text'

# Extract the PIL Image object from the potentially nested structure
# This accounts for how datasets might store Image features as a dict with 'bytes'
image_to_inspect = None
if isinstance(sample[img_key], dict) and 'bytes' in sample[img_key]:
    # It's a datasets Image feature in dict format, load from bytes
    image_to_inspect = Image.open(BytesIO(sample[img_key]['bytes'])).convert('RGB')
else:
    # If it's already a PIL Image (as it should ideally be), use it directly
    image_to_inspect = sample[img_key]


print(f"\nImage type     : {type(image_to_inspect)}")
print(f"Image size     : {image_to_inspect.size}")
print(f"Markdown chars : {len(sample[md_key])}")
print(f"\n--- Markdown Preview (first 400 chars) ---")
print(sample[md_key][:400])
# Out:
# Keys in sample: ['image', 'markdown']
#
# Image type     : <class 'PIL.Image.Image'>
# Image size     : (816, 1056)
# Markdown chars : 4767
#
# --- Markdown Preview (first 400 chars) ---
# ground state is two-fold degenerate, and when \(B>B_{\text{th}}\) the ground state becomes non-degenerate and the corresponding wave function is given by
#
# \[|\psi_{0}\rangle=|-\frac{1}{2},-1\rangle,\] (39)
#
# which is obviously of no entanglement. Then, the ground-state negativity forms a platform when \(0<B<B_{\text{th}}\). The jump of negativity at \(B=B_{\text{th}}\) is due to the level crossing.

# %%
# ── Visualize first 4 samples ─────────────────────────────────────────────────
import matplotlib.pyplot as plt
from io import BytesIO

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle("Nougat Dataset — Document Image Samples", fontsize=16, fontweight='bold')

for idx, ax in enumerate(axes.flatten()):
    s   = nougat_dataset[idx]
    # Extract the PIL Image object from the potentially nested structure
    # This accounts for how datasets might store Image features as a dict with 'bytes'
    img_raw = s.get('image', s.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        img = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        img = img_raw

    md  = s.get('markdown', s.get('text', ''))
    ax.imshow(img)
    ax.set_title(f"Sample {idx+1}  |  Markdown: {len(md)} chars", fontsize=11)
    ax.axis('off')

plt.tight_layout()
save_path = os.path.join(WORK_DIR, 'dataset_samples.png')
plt.savefig(save_path, dpi=120, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")
# Out:
# Saved → /content/vlm_assignment/dataset_samples.png

# %%
# ── Dataset statistics (sample 200 rows for speed) ───────────────────────────
md_lengths  = []
img_sizes   = []

for i in range(min(200, len(nougat_dataset))):
    s = nougat_dataset[i]
    md_lengths.append(len(s.get('markdown', s.get('text', ''))))

    # Correctly extract PIL Image from the dataset's image dictionary
    img_raw = s.get('image', s.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        img_pil = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        img_pil = img_raw

    if img_pil: # Ensure image was successfully loaded
        img_sizes.append(img_pil.size)

print("=== Dataset Statistics ===")
print(f"Markdown avg length  : {np.mean(md_lengths):.0f} chars")
print(f"Markdown max length  : {np.max(md_lengths)} chars")
print(f"Markdown min length  : {np.min(md_lengths)} chars")
print(f"Most common img size : {max(set(img_sizes), key=img_sizes.count) if img_sizes else 'N/A'}")
# Out:
# === Dataset Statistics ===
# Markdown avg length  : 3095 chars
# Markdown max length  : 7065 chars
# Markdown min length  : 147 chars
# Most common img size : (816, 1056)

# %% [markdown]
# ---
# ## Part 2: Data Preparation — ChatML Format
#
# Each sample is converted into **ChatML format** required by Qwen2-VL:
# ```
# system  → expert document parser instruction
# user    → [image] + instruction text
# assistant → ground truth markdown
# ```

# %%
# ── Define prompts ────────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "You are an expert document parser. "
    "Convert the given document image into clean, structured Markdown. "
    "Preserve headings, tables, equations, lists, and formatting accurately."
)

INSTRUCTION_PROMPT = (
    "Please convert this document image into structured Markdown format. "
    "Include all text, headings, tables, lists, and mathematical equations."
)


def build_chatml_sample(image, markdown_target):
    """Convert raw image+markdown into Qwen2-VL ChatML format."""
    return {
        "messages": [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": image},
                    {"type": "text",  "text": INSTRUCTION_PROMPT}
                ]
            },
            {
                "role": "assistant",
                "content": markdown_target
            }
        ]
    }


# Show one converted example
s0       = nougat_dataset[0]
img0     = s0.get('image', s0.get('img'))
md0      = s0.get('markdown', s0.get('text', ''))
example  = build_chatml_sample(img0, md0)

print("ChatML structure")
print("  Keys    :", list(example.keys()))
print("  Roles   :", [m['role'] for m in example['messages']])
print("  User content types:",
      [c['type'] for c in example['messages'][1]['content']])
print("\nAssistant response preview:")
print(example['messages'][2]['content'][:300])
# Out:
# ChatML structure
#   Keys    : ['messages']
#   Roles   : ['system', 'user', 'assistant']
#   User content types: ['image', 'text']
#
# Assistant response preview:
# ground state is two-fold degenerate, and when \(B>B_{\text{th}}\) the ground state becomes non-degenerate and the corresponding wave function is given by
#
# \[|\psi_{0}\rangle=|-\frac{1}{2},-1\rangle,\] (39)
#
# which is obviously of no entanglement. Then, the ground-state negativity forms a platform whe

# %% [markdown]
# ---
# ## Part 3: Dataset Split — 80% Train / 20% Validation

# %%
# ── Subset selection for Colab T4 (15 GB VRAM) ───────────────────────────────
# Using 500 samples — fast enough for Colab, representative enough to learn
# Increase TOTAL_SAMPLES if you have Colab Pro with A100
TOTAL_SAMPLES = min(500, len(nougat_dataset))
TRAIN_RATIO   = 0.80

n_train = int(TOTAL_SAMPLES * TRAIN_RATIO)
n_val   = TOTAL_SAMPLES - n_train

shuffled   = nougat_dataset.shuffle(seed=42)
train_data = shuffled.select(range(n_train))
val_data   = shuffled.select(range(n_train, n_train + n_val))

print(f"Total subset   : {TOTAL_SAMPLES}")
print(f"Training set   : {len(train_data)}  (80%)")
print(f"Validation set : {len(val_data)}  (20%)")

# Visualize split
fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(['Train', 'Validation'], [len(train_data), len(val_data)],
       color=['#2196F3', '#FF9800'], edgecolor='black', linewidth=0.8)
ax.set_title('Dataset Split (80/20)', fontsize=13, fontweight='bold')
ax.set_ylabel('Samples')
for i, v in enumerate([len(train_data), len(val_data)]):
    ax.text(i, v + 2, str(v), ha='center', fontweight='bold', fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'dataset_split.png'), dpi=120)
plt.show()
# Out:
# Total subset   : 500
# Training set   : 400  (80%)
# Validation set : 100  (20%)

# %% [markdown]
# ---
# ## Part 4: Model Setup — Qwen2-VL-2B + QLoRA
#
# | Component | Setting | Why |
# |-----------|---------|-----|
# | Quantization | 4-bit NF4 | Fits 2B model in Colab T4 15GB |
# | LoRA rank | 16 | Good capacity without OOM |
# | LoRA alpha | 32 | 2× rank — standard scaling |
# | Image resolution | 512px | Balances quality vs memory |

# %%
from transformers import BitsAndBytesConfig, AutoProcessor, Qwen2VLForConditionalGeneration, TrainingArguments
from peft import LoraConfig, TaskType, get_peft_model
import torch

MODEL_NAME = "Qwen/Qwen2-VL-2B-Instruct"

# ── 4-bit quantization config ─────────────────────────────────────────────────
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,  # saves ~0.4 bits/param extra
    bnb_4bit_quant_type="nf4",       # NF4 is best for normally distributed weights
    bnb_4bit_compute_dtype=torch.float16
)

# ── Load processor (handles both image & text tokenization) ───────────────────
print("Loading processor...")
processor = AutoProcessor.from_pretrained(
    MODEL_NAME,
    min_pixels=256 * 28 * 28,
    max_pixels=512 * 28 * 28   # Colab T4 memory constraint
)

# ── Load base model in 4-bit ──────────────────────────────────────────────────
print("Loading Qwen2-VL-2B in 4-bit quantized form...")
print("(This downloads ~1.5GB — takes 3-5 mins on first run)")

base_model = Qwen2VLForConditionalGeneration.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",          # auto assigns to GPU
    torch_dtype=torch.float16,
    trust_remote_code=True
)

print("\n✅ Base model loaded!")
print(f"Model dtype : {base_model.dtype}")
print(f"Device      : {next(base_model.parameters()).device}")

# Show GPU memory usage
mem_used = torch.cuda.memory_allocated() / 1024**3
mem_total = torch.cuda.get_device_properties(0).total_memory / 1024**3
print(f"GPU Memory  : {mem_used:.1f} GB / {mem_total:.1f} GB used")
# Out:
# Loading processor...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading Qwen2-VL-2B in 4-bit quantized form...
# (This downloads ~1.5GB — takes 3-5 mins on first run)
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# ✅ Base model loaded!
# Model dtype : torch.float16
# Device      : cuda:0
# GPU Memory  : 1.4 GB / 14.6 GB used

# %%
# ── LoRA configuration ────────────────────────────────────────────────────────
lora_config = LoraConfig(
    r=16,                        # rank — how much capacity LoRA adds
    lora_alpha=32,               # scaling: alpha/r = 2 (standard)
    target_modules=[             # which layers get LoRA adapters
        "q_proj", "k_proj", "v_proj", "o_proj",  # attention
        "gate_proj", "up_proj", "down_proj"       # FFN
    ],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

# Apply LoRA adapters to the quantized base model
model = get_peft_model(base_model, lora_config)

# This shows trainable vs total params — should be ~0.5-2%
model.print_trainable_parameters()

# Enable gradient checkpointing to save memory on Colab
model.enable_input_require_grads()
print("\n✅ QLoRA model ready!")
# Out:
# trainable params: 18,464,768 || all params: 2,227,450,368 || trainable%: 0.8290
#
# ✅ QLoRA model ready!

# %%
from torch.utils.data import Dataset
from io import BytesIO # Added this import

# ── Custom Dataset class ──────────────────────────────────────────────────────
class NougatVLMDataset(Dataset):
    """
    Converts Nougat HF dataset into tokenized inputs for Qwen2-VL.
    Each item returns: input_ids, attention_mask, pixel_values, labels
    """
    def __init__(self, hf_dataset, processor, max_length=512):
        self.data       = hf_dataset
        self.processor  = processor
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        img_raw  = sample.get('image', sample.get('img'))
        md     = sample.get('markdown', sample.get('text', ''))

        # Correctly extract PIL Image object from the potentially nested structure
        if isinstance(img_raw, dict) and 'bytes' in img_raw:
            image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
        else:
            image = img_raw.convert('RGB') # If it's already a PIL Image, convert directly

        # Resize to save GPU memory on Colab T4
        image = image.resize((512, 512), Image.LANCZOS)

        # Build ChatML messages
        messages = [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": image},
                    {"type": "text",  "text": INSTRUCTION_PROMPT}
                ]
            },
            {
                "role": "assistant",
                "content": md
            }
        ]

        # Apply Qwen2 chat template
        text = self.processor.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=False
        )

        # Tokenize image + text together
        inputs = self.processor(
            text=[text],
            images=[image],
            return_tensors="pt",
            padding="max_length",
            truncation=True,
            max_length=self.max_length
        )

        item           = {k: v.squeeze(0) for k, v in inputs.items()}
        item["labels"] = item["input_ids"].clone()
        return item


# Build datasets
train_dataset = NougatVLMDataset(train_data, processor, max_length=512)
val_dataset   = NougatVLMDataset(val_data,   processor, max_length=512)

print(f"Train dataset : {len(train_dataset)} samples")
print(f"Val dataset   : {len(val_dataset)} samples")

# Quick check — one item
test_item = train_dataset[0]
print("\nSample keys       :", list(test_item.keys()))
print("input_ids shape   :", test_item['input_ids'].shape)
# Out:
# Train dataset : 400 samples
# Val dataset   : 100 samples
#
# Sample keys       : ['input_ids', 'attention_mask', 'mm_token_type_ids', 'pixel_values', 'image_grid_thw', 'labels']
# input_ids shape   : torch.Size([512])

# %%
from transformers import BitsAndBytesConfig, AutoProcessor, Qwen2VLForConditionalGeneration, TrainingArguments, Trainer
from peft import LoraConfig, TaskType, get_peft_model
import torch

MODEL_NAME = "Qwen/Qwen2-VL-2B-Instruct"

# ── 4-bit quantization config ─────────────────────────────────────────────────
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,  # saves ~0.4 bits/param extra
    bnb_4bit_quant_type="nf4",       # NF4 is best for normally distributed weights
    bnb_4bit_compute_dtype=torch.float16
)

# ── Load processor (handles both image & text tokenization) ───────────────────
print("Loading processor...")
processor = AutoProcessor.from_pretrained(
    MODEL_NAME,
    min_pixels=256 * 28 * 28,
    max_pixels=512 * 28 * 28   # Colab T4 memory constraint
)

# ── Load base model in 4-bit ──────────────────────────────────────────────────
print("Loading Qwen2-VL-2B in 4-bit quantized form...")
print("(This downloads ~1.5GB — takes 3-5 mins on first run)")

base_model = Qwen2VLForConditionalGeneration.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",          # auto assigns to GPU
    torch_dtype=torch.float16,
    trust_remote_code=True
)

print("\n✅ Base model loaded!")
print(f"Model dtype : {base_model.dtype}")
print(f"Device      : {next(base_model.parameters()).device}")

# Show GPU memory usage
mem_used = torch.cuda.memory_allocated() / 1024**3
mem_total = torch.cuda.get_device_properties(0).total_memory / 1024**3
print(f"GPU Memory  : {mem_used:.1f} GB / {mem_total:.1f} GB used")
lora_config = LoraConfig(
    r=16,                        # rank — how much capacity LoRA adds
    lora_alpha=32,               # scaling: alpha/r = 2 (standard)
    target_modules=[             # which layers get LoRA adapters
        "q_proj", "k_proj", "v_proj", "o_proj",  # attention
        "gate_proj", "up_proj", "down_proj"       # FFN
    ],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM
)

# Apply LoRA adapters to the quantized base model
model = get_peft_model(base_model, lora_config)

# This shows trainable vs total params — should be ~0.5-2%
model.print_trainable_parameters()

# Enable gradient checkpointing to save memory on Colab
model.enable_input_require_grads()
print("\n✅ QLoRA model ready!")
from torch.utils.data import Dataset
from io import BytesIO # Added this import

# ── Custom Dataset class ──────────────────────────────────────────────────────
class NougatVLMDataset(Dataset):
    """
    Converts Nougat HF dataset into tokenized inputs for Qwen2-VL.
    Each item returns: input_ids, attention_mask, pixel_values, labels
    """
    def __init__(self, hf_dataset, processor, max_length=512):
        self.data       = hf_dataset
        self.processor  = processor
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        img_raw  = sample.get('image', sample.get('img'))
        md     = sample.get('markdown', sample.get('text', ''))

        # Correctly extract PIL Image object from the potentially nested structure
        if isinstance(img_raw, dict) and 'bytes' in img_raw:
            image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
        else:
            image = img_raw.convert('RGB') # If it's already a PIL Image, convert directly

        # Resize to save GPU memory on Colab T4
        image = image.resize((512, 512), Image.LANCZOS)

        # Build ChatML messages
        messages = [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": [
                    {"type": "image", "image": image},
                    {"type": "text",  "text": INSTRUCTION_PROMPT}
                ]
            },
            {
                "role": "assistant",
                "content": md
            }
        ]

        # Apply Qwen2 chat template
        text = self.processor.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=False
        )

        # Tokenize image + text together
        inputs = self.processor(
            text=[text],
            images=[image],
            return_tensors="pt",
            padding="max_length",
            truncation=True,
            max_length=self.max_length
        )

        item           = {k: v.squeeze(0) for k, v in inputs.items()}
        item["labels"] = item["input_ids"].clone()
        return item


# Build datasets
train_dataset = NougatVLMDataset(train_data, processor, max_length=512)
val_dataset   = NougatVLMDataset(val_data,   processor, max_length=512)

print(f"Train dataset : {len(train_dataset)} samples")
print(f"Val dataset   : {len(val_dataset)} samples")

# Quick check — one item
test_item = train_dataset[0]
print("\nSample keys       :", list(test_item.keys()))
print("input_ids shape   :", test_item['input_ids'].shape)

# ── Training Arguments — Colab T4 optimized ───────────────────────────────────
training_args = TrainingArguments(
    output_dir                  = os.path.join(WORK_DIR, 'checkpoints'),
    num_train_epochs            = 3,
    per_device_train_batch_size = 1,     # T4 has 15GB — keep batch=1
    per_device_eval_batch_size  = 1,
    gradient_accumulation_steps = 8,     # effective batch = 8
    learning_rate               = 1e-4,
    lr_scheduler_type           = "cosine",
    warmup_ratio                = 0.05,
    fp16                        = True,  # mixed precision for T4
    eval_strategy               = "epoch", # Renamed from evaluation_strategy
    save_strategy               = "epoch", # Renamed from save_strategy
    load_best_model_at_end      = True,
    metric_for_best_model       = "eval_loss",
    logging_steps               = 10,
    report_to                   = "none",   # disable wandb
    dataloader_num_workers      = 2,
    remove_unused_columns       = False,
    label_names                 = ["labels"],
    # Colab-specific: save memory
    gradient_checkpointing      = True,
    optim                       = "paged_adamw_8bit",  # 8-bit optimizer
)

trainer = Trainer(
    model         = model,
    args          = training_args,
    train_dataset = train_dataset,
    eval_dataset  = val_dataset,
)

steps_per_epoch = len(train_dataset) // training_args.per_device_train_batch_size
print(f"Steps per epoch     : {steps_per_epoch}")
print(f"Total train steps   : {steps_per_epoch * training_args.num_train_epochs}")
print(f"Effective batch size: {training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps}")
# Out:
# Loading processor...
# Loading Qwen2-VL-2B in 4-bit quantized form...
# (This downloads ~1.5GB — takes 3-5 mins on first run)
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# ✅ Base model loaded!
# Model dtype : torch.float16
# Device      : cuda:0
# GPU Memory  : 3.9 GB / 14.6 GB used
# trainable params: 18,464,768 || all params: 2,227,450,368 || trainable%: 0.8290
#
# ✅ QLoRA model ready!
# Train dataset : 400 samples
# Val dataset   : 100 samples
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Sample keys       : ['input_ids', 'attention_mask', 'mm_token_type_ids', 'pixel_values', 'image_grid_thw', 'labels']
# input_ids shape   : torch.Size([512])
# Steps per epoch     : 400
# Total train steps   : 1200
# Effective batch size: 8

# %%
# ── Fine-Tune! ────────────────────────────────────────────────────────────────
print("Starting QLoRA Fine-Tuning...")
print("=" * 55)

train_result = trainer.train()

print("=" * 55)
print(f"✅ Training complete!")
print(f"Training loss : {train_result.training_loss:.4f}")
print(f"Runtime       : {train_result.metrics.get('train_runtime', 0)/60:.1f} mins")
# Out:
# Starting QLoRA Fine-Tuning...
# =======================================================
# [transformers] `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 31:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.207169</td>
#       <td>5.186529</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.104657</td>
#       <td>5.110566</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.101184</td>
#       <td>5.106123</td>
#     </tr>
#   </tbody>
# </table><p>
# =======================================================
# ✅ Training complete!
# Training loss : 5.8045
# Runtime       : 32.1 mins

# %%
# ── Save fine-tuned model locally and to Google Drive ────────────────────────
MODEL_DIR = os.path.join(WORK_DIR, 'checkpoints') # Define MODEL_DIR
model.save_pretrained(MODEL_DIR)
processor.save_pretrained(MODEL_DIR)
print(f"Model saved locally → {MODEL_DIR}")

# Also copy to Drive so it survives Colab session reset
import shutil
drive_model_dir = os.path.join(DRIVE_SAVE_DIR, 'finetuned_model')
shutil.copytree(MODEL_DIR, drive_model_dir, dirs_exist_ok=True)
print(f"Model saved to Drive → {drive_model_dir}")
# Out:
# Model saved locally → /content/vlm_assignment/checkpoints
# Model saved to Drive → /content/drive/MyDrive/GenAI_Assignment5/finetuned_model

# %% [markdown]
# ---
# ## Fine-Tuning Results: Training & Validation Loss

# %%
# ── Extract loss logs ─────────────────────────────────────────────────────────
log_history = trainer.state.log_history

train_steps  = [x['step'] for x in log_history if 'loss' in x and 'eval_loss' not in x]
train_losses = [x['loss'] for x in log_history if 'loss' in x and 'eval_loss' not in x]
eval_epochs  = [x['epoch']     for x in log_history if 'eval_loss' in x]
eval_losses  = [x['eval_loss'] for x in log_history if 'eval_loss' in x]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("QLoRA Fine-Tuning Results — Google Colab (T4)",
             fontsize=14, fontweight='bold')

axes[0].plot(train_steps, train_losses, color='#2196F3', linewidth=2)
axes[0].set_title('Training Loss')
axes[0].set_xlabel('Step')
axes[0].set_ylabel('Loss')
axes[0].grid(True, alpha=0.3)

axes[1].plot(eval_epochs, eval_losses, color='#E53935', linewidth=2,
             marker='o', markersize=9)
axes[1].set_title('Validation Loss (per epoch)')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
loss_path = os.path.join(WORK_DIR, 'training_curves.png')
plt.savefig(loss_path, dpi=130, bbox_inches='tight')
plt.show()

print(f"Final Training Loss   : {train_losses[-1]:.4f}" if train_losses else "N/A")
print(f"Final Validation Loss : {eval_losses[-1]:.4f}"  if eval_losses  else "N/A")
# Out:
# Final Training Loss   : 5.1012
# Final Validation Loss : 5.1061

# %% [markdown]
# ---
# ## Part 5: Markdown Generation on Validation Images

# %%
# ── Load fine-tuned model for inference ──────────────────────────────────────
# Clear GPU cache before loading
import gc # Import the gc module
import torch
from peft import PeftModel # Import PeftModel

gc.collect()
torch.cuda.empty_cache()

ft_model = PeftModel.from_pretrained(
    base_model,
    MODEL_DIR,
    is_trainable=False
)
ft_model.eval()
print("✅ Fine-tuned model loaded for inference!")
# Out:
# ✅ Fine-tuned model loaded for inference!

# %%
# ── Inference function ────────────────────────────────────────────────────────
def generate_markdown(model, processor, image, prompt_style="standard", max_new_tokens=512):
    """
    Generate Markdown from a document image.

    Args:
        prompt_style: 'standard' | 'detailed' | 'minimal'
    Returns:
        Generated markdown string
    """
    prompts = {
        "standard" : INSTRUCTION_PROMPT,
        "detailed" : (
            "Carefully analyze this document image. Extract ALL content: "
            "section headings (use #, ##, ###), body text, bullet lists, "
            "numbered lists, tables (use Markdown table syntax), "
            "equations (wrap in $...$), and captions. Output clean Markdown."
        ),
        "minimal"  : "Convert this document image to Markdown."
    }

    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": [
            {"type": "image", "image": image},
            {"type": "text",  "text": prompts.get(prompt_style, INSTRUCTION_PROMPT)}
        ]}
    ]

    text   = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = processor(text=[text], images=[image], return_tensors="pt").to(model.device)

    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            temperature=None,
            top_p=None
        )

    # Only decode newly generated tokens (not the prompt)
    new_tokens = output_ids[:, inputs['input_ids'].shape[1]:]
    return processor.decode(new_tokens[0], skip_special_tokens=True)


print("generate_markdown() ready!")
# Out:
# generate_markdown() ready!

# %%
# ── Generate on 3 validation images ──────────────────────────────────────────
val_results = []

for i in range(3):
    sample = val_data[i]

    # Correctly extract PIL Image object from the potentially nested structure
    img_raw = sample.get('image', sample.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        image = img_raw.convert('RGB') # If it's already a PIL Image

    gt     = sample.get('markdown', sample.get('text', ''))
    img_r  = image.resize((512, 512), Image.LANCZOS)

    generated = generate_markdown(ft_model, processor, img_r)
    val_results.append({"image": image, "ground_truth": gt, "generated": generated})
    print(f"  Val sample {i+1}: generated {len(generated)} chars")

print("\n✅ Validation generation done!")
# Out:
#   Val sample 1: generated 1183 chars
#   Val sample 2: generated 864 chars
#   Val sample 3: generated 2602 chars
#
# ✅ Validation generation done!

# %% [markdown]
# ---
# ## Visualization Module — Image | Ground Truth | Generated

# %%
def visualize_results(results, title_prefix="Sample", save_dir=WORK_DIR):
    """Display 3-column view: Input Image | Ground Truth | Generated Markdown."""
    for i, r in enumerate(results):
        fig, axes = plt.subplots(1, 3, figsize=(20, 8))
        fig.suptitle(f"{title_prefix} {i+1} — Document to Markdown",
                     fontsize=14, fontweight='bold', y=1.01)

        # Col 1: Document image
        axes[0].imshow(r['image'])
        axes[0].set_title('Input Document Image', fontsize=12, color='#1565C0',
                          fontweight='bold')
        axes[0].axis('off')

        # Col 2: Ground Truth
        gt_text = r['ground_truth'][:900] + ('...' if len(r['ground_truth']) > 900 else '')
        axes[1].text(0.02, 0.98, gt_text, transform=axes[1].transAxes,
                     fontsize=7, verticalalignment='top', fontfamily='monospace',
                     bbox=dict(boxstyle='round', facecolor='#E8F5E9', alpha=0.85))
        axes[1].set_title('Ground Truth Markdown', fontsize=12, color='#2E7D32',
                          fontweight='bold')
        axes[1].axis('off')

        # Col 3: Generated
        gen_text = r['generated'][:900] + ('...' if len(r['generated']) > 900 else '')
        axes[2].text(0.02, 0.98, gen_text, transform=axes[2].transAxes,
                     fontsize=7, verticalalignment='top', fontfamily='monospace',
                     bbox=dict(boxstyle='round', facecolor='#FFF3E0', alpha=0.85))
        axes[2].set_title('Generated Markdown (Fine-Tuned)', fontsize=12, color='#E65100',
                          fontweight='bold')
        axes[2].axis('off')

        plt.tight_layout()
        fname = os.path.join(save_dir, f'{title_prefix.lower().replace(" ","_")}_{i+1}.png')
        plt.savefig(fname, dpi=130, bbox_inches='tight')
        plt.show()
        print(f"  Saved → {fname}")


# Visualize validation results
visualize_results(val_results, title_prefix="Validation")
# Out:
# /tmp/ipykernel_15438/3385999075.py:32: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
#   Saved → /content/vlm_assignment/validation_1.png
#   Saved → /content/vlm_assignment/validation_2.png
#   Saved → /content/vlm_assignment/validation_3.png

# %% [markdown]
# ---
# ## Part 6A: Testing — 3 Training Images (Seen)

# %%
train_results = []

for i in range(3):
    sample    = train_data[i]

    # Correctly extract PIL Image object from the potentially nested structure
    img_raw = sample.get('image', sample.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        image = img_raw.convert('RGB') # If it's already a PIL Image

    gt        = sample.get('markdown', sample.get('text', ''))
    generated = generate_markdown(ft_model, processor, image.resize((512,512), Image.LANCZOS))
    train_results.append({"image": image, "ground_truth": gt, "generated": generated})
    print(f"  Train sample {i+1}: {len(generated)} chars")

visualize_results(train_results, title_prefix="Train")
# Out:
#   Train sample 1: 976 chars
#   Train sample 2: 1090 chars
#   Train sample 3: 1714 chars
# /tmp/ipykernel_15438/3385999075.py:32: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
#   Saved → /content/vlm_assignment/train_1.png
#   Saved → /content/vlm_assignment/train_2.png
#   Saved → /content/vlm_assignment/train_3.png

# %% [markdown]
# ## Part 6B: Testing — 3 Unseen Document Images

# %%
# Load unseen samples — use out-of-split indices
try:
    unseen_ds = load_dataset("jxu124/nougat", split="test[:3]", trust_remote_code=True)
    unseen_images = [s.get('image', s.get('img')) for s in unseen_ds]
    unseen_gts    = [s.get('markdown', s.get('text', '')) for s in unseen_ds]
    print("Loaded from test split.")
except Exception:
    # Fallback: pick samples beyond our train+val range
    print("Test split not available — using out-of-subset samples.")
    end  = n_train + n_val
    ood  = shuffled.select(range(end, min(end + 3, len(shuffled))))
    unseen_images = [s.get('image', s.get('img')) for s in ood]
    unseen_gts    = [s.get('markdown', s.get('text', '')) for s in ood]

unseen_results = []
for i, (img_raw, gt) in enumerate(zip(unseen_images, unseen_gts)):
    # Correctly extract PIL Image object from the potentially nested structure
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        image = img_raw.convert('RGB') # If it's already a PIL Image

    generated = generate_markdown(ft_model, processor, image.resize((512,512), Image.LANCZOS))
    unseen_results.append({"image": image, "ground_truth": gt, "generated": generated})
    print(f"  Unseen sample {i+1}: {len(generated)} chars")

visualize_results(unseen_results, title_prefix="Unseen")
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'jxu124/nougat' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# ERROR:datasets.load:`trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'jxu124/nougat' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# Test split not available — using out-of-subset samples.
#   Unseen sample 1: 1676 chars
#   Unseen sample 2: 1988 chars
#   Unseen sample 3: 1515 chars
# /tmp/ipykernel_15438/3385999075.py:32: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
#   Saved → /content/vlm_assignment/unseen_1.png
#   Saved → /content/vlm_assignment/unseen_2.png
#   Saved → /content/vlm_assignment/unseen_3.png

# %% [markdown]
# ---
# ## Quantitative Comparison — ROUGE Scores (Actual vs Predicted)

# %%
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)

def compute_rouge(results, split_name):
    r1_list, rL_list = [], []
    print(f"\n{'='*50}")
    print(f"ROUGE — {split_name}")
    print(f"{'='*50}")
    for i, r in enumerate(results):
        s  = scorer.score(r['ground_truth'], r['generated'])
        r1 = s['rouge1'].fmeasure
        rL = s['rougeL'].fmeasure
        r1_list.append(r1)
        rL_list.append(rL)
        print(f"  Sample {i+1}: ROUGE-1={r1:.3f} | ROUGE-L={rL:.3f}")
    print(f"  Average : ROUGE-1={np.mean(r1_list):.3f} | ROUGE-L={np.mean(rL_list):.3f}")
    return r1_list, rL_list

val_r1,    val_rL    = compute_rouge(val_results,    "Validation")
train_r1,  train_rL  = compute_rouge(train_results,  "Train (seen)")
unseen_r1, unseen_rL = compute_rouge(unseen_results, "Unseen")
# Out:
# ==================================================
# ROUGE — Validation
# ==================================================
#   Sample 1: ROUGE-1=0.295 | ROUGE-L=0.276
#   Sample 2: ROUGE-1=0.840 | ROUGE-L=0.840
#   Sample 3: ROUGE-1=0.797 | ROUGE-L=0.782
#   Average : ROUGE-1=0.644 | ROUGE-L=0.632
#
# ==================================================
# ROUGE — Train (seen)
# ==================================================
#   Sample 1: ROUGE-1=0.138 | ROUGE-L=0.138
#   Sample 2: ROUGE-1=0.161 | ROUGE-L=0.161
#   Sample 3: ROUGE-1=0.646 | ROUGE-L=0.592
#   Average : ROUGE-1=0.315 | ROUGE-L=0.297
#
# ==================================================
# ROUGE — Unseen
# ==================================================
#   Sample 1: ROUGE-1=0.273 | ROUGE-L=0.190
#   Sample 2: ROUGE-1=0.863 | ROUGE-L=0.850
#   Sample 3: ROUGE-1=0.756 | ROUGE-L=0.731
#   Average : ROUGE-1=0.631 | ROUGE-L=0.590

# %%
# ── ROUGE bar chart ───────────────────────────────────────────────────────────
splits  = ['Train (seen)', 'Validation', 'Unseen']
r1_avgs = [np.mean(train_r1), np.mean(val_r1), np.mean(unseen_r1)]
rL_avgs = [np.mean(train_rL), np.mean(val_rL), np.mean(unseen_rL)]

x, w = np.arange(3), 0.35
fig, ax = plt.subplots(figsize=(9, 5))
b1 = ax.bar(x - w/2, r1_avgs, w, label='ROUGE-1', color='#42A5F5', edgecolor='black')
b2 = ax.bar(x + w/2, rL_avgs, w, label='ROUGE-L', color='#EF5350', edgecolor='black')
ax.set_title('ROUGE Scores — Actual vs Predicted', fontsize=13, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(splits)
ax.set_ylabel('F-measure')
ax.set_ylim(0, 1)
ax.legend()
ax.grid(axis='y', alpha=0.3)
for bar in list(b1) + list(b2):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.015,
            f'{bar.get_height():.2f}', ha='center', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'rouge_comparison.png'), dpi=130)
plt.show()

# %% [markdown]
# ---
# ## 🎁 BONUS TASK 1: 2 Epochs vs 5 Epochs Comparison

# %%
def train_n_epochs(n_epochs, output_subdir):
    """Train a fresh QLoRA model for n_epochs and return log history."""
    # Fresh model for each run
    gc.collect()
    torch.cuda.empty_cache()

    m = get_peft_model(base_model, lora_config)
    m.enable_input_require_grads()

    args = TrainingArguments(
        output_dir                  = os.path.join(WORK_DIR, output_subdir),
        num_train_epochs            = n_epochs,
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        learning_rate               = 1e-4,
        fp16                        = True,
        eval_strategy               = "epoch", # Corrected argument name
        save_strategy               = "no",
        logging_steps               = 10,
        report_to                   = "none",
        remove_unused_columns       = False,
        label_names                 = ["labels"],
        gradient_checkpointing      = True,
        optim                       = "paged_adamw_8bit",
    )
    t = Trainer(model=m, args=args,
                train_dataset=train_dataset,
                eval_dataset=val_dataset)
    t.train()
    return t.state.log_history


print("Training 2-epoch model...")
history_2ep = train_n_epochs(2, 'run_2ep')

print("\nTraining 5-epoch model...")
history_5ep = train_n_epochs(5, 'run_5ep')

print("\n✅ Both runs complete!")
# Out:
# Training 2-epoch model...
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 21:07, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.209682</td>
#       <td>5.194445</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.122219</td>
#       <td>5.129522</td>
#     </tr>
#   </tbody>
# </table><p>
# Training 5-epoch model...
#     <div>
#
#       <progress value='203' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [203/250 42:57 < 10:02, 0.08 it/s, Epoch 4.04/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.185783</td>
#       <td>5.169460</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.098581</td>
#       <td>5.104881</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.079227</td>
#       <td>5.098100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.066279</td>
#       <td>5.096165</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 53:14, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.185783</td>
#       <td>5.169460</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.098581</td>
#       <td>5.104881</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.079227</td>
#       <td>5.098100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.066279</td>
#       <td>5.096165</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.086129</td>
#       <td>5.096760</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Both runs complete!

# %%
def extract_eval(history):
    ep = [x['epoch']     for x in history if 'eval_loss' in x]
    lv = [x['eval_loss'] for x in history if 'eval_loss' in x]
    return ep, lv

ep2, lv2 = extract_eval(history_2ep)
ep5, lv5 = extract_eval(history_5ep)

fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(ep2, lv2, 'o-', color='#FF7043', lw=2, ms=9, label='2 Epochs')
ax.plot(ep5, lv5, 's-', color='#43A047', lw=2, ms=9, label='5 Epochs')
ax.set_title('BONUS 1: Validation Loss — 2 vs 5 Epochs', fontsize=13, fontweight='bold')
ax.set_xlabel('Epoch')
ax.set_ylabel('Validation Loss')
ax.legend(fontsize=12)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'bonus_epoch_comparison.png'), dpi=130)
plt.show()

print(f"2-epoch final val loss : {lv2[-1]:.4f}")
print(f"5-epoch final val loss : {lv5[-1]:.4f}")
print("Insight: More epochs → lower loss, but risk of overfitting on small datasets.")
# Out:
# 2-epoch final val loss : 5.1295
# 5-epoch final val loss : 5.0968
# Insight: More epochs → lower loss, but risk of overfitting on small datasets.

# %% [markdown]
# ---
# ## 🎁 BONUS TASK 2: Prompt Style Comparison (Standard vs Detailed vs Minimal)

# %%
# Use the same val image for fair comparison
test_sample = val_data[0]

# Correctly extract PIL Image object from the potentially nested structure
img_raw = test_sample.get('image', test_sample.get('img'))
if isinstance(img_raw, dict) and 'bytes' in img_raw:
    test_image = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
else:
    test_image = img_raw.convert('RGB') # If it's already a PIL Image

test_gt     = test_sample.get('markdown', test_sample.get('text', ''))
test_img_r  = test_image.resize((512, 512), Image.LANCZOS)

styles  = ["standard", "detailed", "minimal"]
outputs = {}

for style in styles:
    out = generate_markdown(ft_model, processor, test_img_r, prompt_style=style)
    outputs[style] = out
    s = scorer.score(test_gt, out)
    print(f"{style:10s}: {len(out):4d} chars | "
          f"ROUGE-1={s['rouge1'].fmeasure:.3f} | ROUGE-L={s['rougeL'].fmeasure:.3f}")
# Out:
# standard  : 1455 chars | ROUGE-1=0.436 | ROUGE-L=0.400
# detailed  : 1357 chars | ROUGE-1=0.421 | ROUGE-L=0.387
# minimal   : 1441 chars | ROUGE-1=0.429 | ROUGE-L=0.391

# %%
# ── Visualize prompt style outputs ────────────────────────────────────────────
fig, axes = plt.subplots(1, 4, figsize=(24, 8))
fig.suptitle('BONUS 2: Prompt Style Comparison on Same Image',
             fontsize=14, fontweight='bold')

axes[0].imshow(test_image)
axes[0].set_title('Input Image', color='#1565C0', fontsize=12, fontweight='bold')
axes[0].axis('off')

cfg = {
    'standard': ('#FFF9C4', '#F57F17'),
    'detailed': ('#E8F5E9', '#2E7D32'),
    'minimal':  ('#FCE4EC', '#880E4F')
}

for ax, style in zip(axes[1:], styles):
    bg, tc = cfg[style]
    txt = outputs[style][:750] + ('...' if len(outputs[style]) > 750 else '')
    ax.text(0.02, 0.98, txt, transform=ax.transAxes, fontsize=6.5,
            verticalalignment='top', fontfamily='monospace',
            bbox=dict(boxstyle='round', facecolor=bg, alpha=0.9))
    ax.set_title(f'{style.capitalize()} Prompt', color=tc, fontsize=12, fontweight='bold')
    ax.axis('off')

plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'bonus_prompt_styles.png'), dpi=130, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_15438/883252069.py:25: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()

# %% [markdown]
# ---
# ## 🎁 BONUS TASK 3: Zero-Shot vs Fine-Tuned Comparison

# %%
zs_r1, ft_r1 = [], []

print("Generating zero-shot outputs (adapters disabled)...")
ft_model.disable_adapter_layers()   # turns off LoRA → pure base model
zs_outs = []
for i in range(3):
    s   = val_data[i]
    img_raw = s.get('image', s.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        img = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        img = img_raw.convert('RGB')
    img = img.resize((512,512), Image.LANCZOS)
    gt  = s.get('markdown', s.get('text', ''))
    zs  = generate_markdown(ft_model, processor, img)
    zs_outs.append({'gt': gt, 'generated': zs})
    print(f"  Sample {i+1} (zero-shot): {len(zs)} chars")

print("\nGenerating fine-tuned outputs (adapters enabled)...")
ft_model.enable_adapter_layers()    # turns LoRA back on
ft_outs = []
for i in range(3):
    s   = val_data[i]
    img_raw = s.get('image', s.get('img'))
    if isinstance(img_raw, dict) and 'bytes' in img_raw:
        img = Image.open(BytesIO(img_raw['bytes'])).convert('RGB')
    else:
        img = img_raw.convert('RGB')
    img = img.resize((512,512), Image.LANCZOS)
    gt  = s.get('markdown', s.get('text', ''))
    ft  = generate_markdown(ft_model, processor, img)
    ft_outs.append({'gt': gt, 'generated': ft})
    print(f"  Sample {i+1} (fine-tuned): {len(ft)} chars")

print("\n=" * 50)
print("BONUS 3: ROUGE Comparison")
print("=" * 50)
for i in range(3):
    zs_s = scorer.score(zs_outs[i]['gt'], zs_outs[i]['generated'])
    ft_s = scorer.score(ft_outs[i]['gt'], ft_outs[i]['generated'])
    zr1  = zs_s['rouge1'].fmeasure
    fr1  = ft_s['rouge1'].fmeasure
    zs_r1.append(zr1)
    ft_r1.append(fr1)
    print(f"  Sample {i+1}: Zero-shot={zr1:.3f} | Fine-tuned={fr1:.3f} | "
          f"Gain={fr1-zr1:+.3f}")

gain = (np.mean(ft_r1) - np.mean(zs_r1)) / (np.mean(zs_r1) + 1e-9) * 100
print(f"\n  Avg Zero-shot ROUGE-1  : {np.mean(zs_r1):.3f}")
print(f"  Avg Fine-tuned ROUGE-1 : {np.mean(ft_r1):.3f}")
print(f"  Improvement            : +{gain:.1f}%")
# Out:
# Generating zero-shot outputs (adapters disabled)...
#   Sample 1 (zero-shot): 1297 chars
#   Sample 2 (zero-shot): 856 chars
#   Sample 3 (zero-shot): 2528 chars
#
# Generating fine-tuned outputs (adapters enabled)...
#   Sample 1 (fine-tuned): 1455 chars
#   Sample 2 (fine-tuned): 760 chars
#   Sample 3 (fine-tuned): 2605 chars
#
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# =
# BONUS 3: ROUGE Comparison
# ==================================================
#   Sample 1: Zero-shot=0.390 | Fine-tuned=0.436 | Gain=+0.046
#   Sample 2: Zero-shot=0.831 | Fine-tuned=0.394 | Gain=-0.438
#   Sample 3: Zero-shot=0.774 | Fine-tuned=0.798 | Gain=+0.024
#
#   Avg Zero-shot ROUGE-1  : 0.665
#   Avg Fine-tuned ROUGE-1 : 0.543
#   Improvement            : +-18.4%

# %%
# ── Bar chart ─────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5))
x, w = np.arange(3), 0.35
ax.bar(x - w/2, zs_r1, w, label='Zero-Shot',  color='#90A4AE', edgecolor='black')
ax.bar(x + w/2, ft_r1, w, label='Fine-Tuned', color='#66BB6A', edgecolor='black')
ax.set_title('BONUS 3: Zero-Shot vs Fine-Tuned (ROUGE-1)',
             fontsize=13, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels([f'Sample {i+1}' for i in range(3)])
ax.set_ylabel('ROUGE-1 F-measure')
ax.set_ylim(0, 1)
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(WORK_DIR, 'bonus_zeroshot_vs_finetuned.png'), dpi=130)
plt.show()

# %% [markdown]
# ---
# ## 🚀 App Deployment: Gradio Interface
#
# > In Colab, `share=True` creates a **public link** via Gradio's tunnel — no server setup needed.

# %%
import gradio as gr

def predict_markdown(image_input, prompt_style):
    """Gradio prediction function — takes numpy image, returns markdown string."""
    if image_input is None:
        return "⚠️ Please upload a document image."
    image_pil = Image.fromarray(image_input).convert('RGB').resize((512, 512), Image.LANCZOS)
    return generate_markdown(ft_model, processor, image_pil, prompt_style=prompt_style)


# Build the Gradio app
with gr.Blocks(title="Document → Markdown | Qwen2-VL QLoRA",
               theme=gr.themes.Soft()) as demo:

    gr.Markdown("""
    # 📄 Document-to-Markdown Generator
    **Model**: Qwen2-VL-2B-Instruct · Fine-tuned with QLoRA · Nougat Dataset
    **Assignment 5 | GenAI AI4009 | NUCES Spring 2026**
    ---
    """)

    with gr.Row():
        with gr.Column(scale=1):
            image_input  = gr.Image(label="📂 Upload Document Image", type="numpy")
            prompt_style = gr.Radio(
                choices=["standard", "detailed", "minimal"],
                value="standard",
                label="Prompt Style",
                info="Detailed = most complete output | Minimal = fastest"
            )
            submit_btn = gr.Button("⚡ Generate Markdown", variant="primary", size="lg")

        with gr.Column(scale=1):
            output_text = gr.Textbox(
                label="Generated Markdown (Raw)",
                lines=20,
                show_copy_button=True
            )
            output_md = gr.Markdown(label="Rendered Preview")

    submit_btn.click(
        fn=predict_markdown,
        inputs=[image_input, prompt_style],
        outputs=[output_text]
    )
    # Auto-render the generated markdown
    output_text.change(fn=lambda x: x, inputs=output_text, outputs=output_md)

# Launch with share=True for Colab public URL
demo.launch(
    share=True,       # generates public gradio.live link — works in Colab
    debug=False,
    quiet=True
)
print("\n✅ Gradio app launched! Click the public URL above.")
# Out:
# /tmp/ipykernel_15438/94354566.py:12: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(title="Document → Markdown | Qwen2-VL QLoRA",
# * Running on public URL: https://e046492aa472f87641.gradio.live
# <div><iframe src="https://e046492aa472f87641.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ✅ Gradio app launched! Click the public URL above.

# %% [markdown]
# ---
# ## 💾 Save All Outputs to Google Drive

# %%
# Copy all generated plots and results to Drive
import shutil

plots = [
    'dataset_samples.png',
    'dataset_split.png',
    'training_curves.png',
    'rouge_comparison.png',
    'bonus_epoch_comparison.png',
    'bonus_prompt_styles.png',
    'bonus_zeroshot_vs_finetuned.png'
]

drive_plots_dir = os.path.join(DRIVE_SAVE_DIR, 'plots')
os.makedirs(drive_plots_dir, exist_ok=True)

for plot in plots:
    src = os.path.join(WORK_DIR, plot)
    if os.path.exists(src):
        shutil.copy(src, os.path.join(drive_plots_dir, plot))
        print(f"  ✅ Copied {plot}")
    else:
        print(f"  ⚠️  Not found: {plot}")

print(f"\nAll outputs saved to: {DRIVE_SAVE_DIR}")
# Out:
#   ✅ Copied dataset_samples.png
#   ✅ Copied dataset_split.png
#   ✅ Copied training_curves.png
#   ✅ Copied rouge_comparison.png
#   ✅ Copied bonus_epoch_comparison.png
#   ✅ Copied bonus_prompt_styles.png
#   ✅ Copied bonus_zeroshot_vs_finetuned.png
#
# All outputs saved to: /content/drive/MyDrive/GenAI_Assignment5

# %% [markdown]
# ---
# ## ✅ Assignment Summary
#
# | Task | Details | Status |
# |------|---------|--------|
# | Environment Setup | Google Colab T4, Drive mounted | ✅ |
# | Part 1: Dataset Exploration | Nougat dataset, 4 samples visualized, stats | ✅ |
# | Part 2: Data Preparation | ChatML format (system/user/assistant) | ✅ |
# | Part 3: Dataset Split | 80% train / 20% validation | ✅ |
# | Part 4: QLoRA Fine-Tuning | Qwen2-VL-2B, 4-bit, LoRA rank=16, 3 epochs | ✅ |
# | Part 5: Markdown Generation | 3 val images generated & visualized | ✅ |
# | Part 6A: Train Image Testing | 3 seen images tested | ✅ |
# | Part 6B: Unseen Image Testing | 3 new document images tested | ✅ |
# | Visualization Module | 3-column: Image \| GT \| Generated | ✅ |
# | ROUGE Comparison | Actual vs Predicted across all splits | ✅ |
# | Gradio App | Upload image → prompt style → Markdown + preview | ✅ |
# | Drive Backup | All outputs + model saved to Google Drive | ✅ |
# | **BONUS 1** | 2 epochs vs 5 epochs validation loss comparison | ✅ |
# | **BONUS 2** | Standard / Detailed / Minimal prompt comparison | ✅ |
# | **BONUS 3** | Zero-shot vs Fine-tuned ROUGE improvement | ✅ |
#
# ### Key Insights
# - **4-bit QLoRA** makes 2B VLM training feasible on a free Colab T4 GPU
# - **Fine-tuning** consistently outperforms zero-shot baseline on ROUGE metrics
# - **More epochs** reduce loss but can overfit on small subsets — 3 is a sweet spot
# - **Detailed prompts** extract more complete structure from complex document pages
# - **Google Drive integration** is critical for Colab — sessions reset after ~12 hours
